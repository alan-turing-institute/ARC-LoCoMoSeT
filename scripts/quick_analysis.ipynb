# %% [markdown]
# # Quick and Dirty Analysis

# %% [markdown]
# Just here to try and make some very basic graphs based on our current work. Probably gonna do some data entry by hand from weights and biases, then just create some super simple graphs.

# %%
import matplotlib.pyplot as plt
import numpy as np
import yaml

# %% [markdown]
# First up just create some results dictionaries by hand:

# %%
# first the validation accuracies
val_acc = {
    "microsoft/swinv2-base-patch4-window8-256": 0.961038961038961,
    "Intel/vit-base-patch16-224-int8-static": 0.21645021645021645,
    "microsoft/swin-base-patch4-window12-384": 0.9653679653679652,
    "facebook/dinov2-base-imagenet1k-1-layer": 0.25,
    "microsoft/swin-large-patch4-window12-384-in22k": 0.9659090909090908,
    "facebook/dinov2-small-imagenet1k-1-layer": 0.29004329004329005,
    "microsoft/beit-base-patch16-224": 0.9453463203463204,
    "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.941017316017316,
    "microsoft/beit-large-patch16-512": 0.9675324675324676,
    "facebook/deit-base-patch16-384": 0.9648268398268398,
    "microsoft/cvt-21-384-22k": 0.9518398268398268,
    "microsoft/cvt-13": 0.9567099567099568,
    "google/vit-large-patch16-224": 0.9437229437229436,
    "google/vit-base-patch16-384": 0.9594155844155844,
    "facebook/deit-base-patch16-224": 0.9475108225108224,
    "apple/mobilevit-xx-small": 0.8679653679653679,
    "apple/mobilevit-small": 0.9442640692640693,
    "facebook/deit-small-patch16-224": 0.9393939393939394,
    "facebook/deit-tiny-patch16-224": 0.9177489177489178,
}

# %%
len(val_acc.keys())
# Out:
# 19

# %%
# write to yaml
with open("oxford-pets_20231110-083306-254553_val_scores.yaml", "w") as f:
    yaml.safe_dump(val_acc, f)

# %%
# Now the metrics
metric_scores = {
    "n_pars": {
        "microsoft/swinv2-base-patch4-window8-256": 86893816,
        "apple/mobilevit-small": 4937632,
        "Intel/vit-base-patch16-224-int8-static": 85798656,
        "microsoft/swin-base-patch4-window12-384": 86878584,
        "facebook/dinov2-base-imagenet1k-1-layer": 86580480,
        "facebook/dinov2-small-imagenet1k-1-layer": 22056576,
        "microsoft/swin-large-patch4-window12-384-in22k": 195198516,
        "microsoft/beit-base-patch16-224-pt22k-ft22k": 85761984,
        "microsoft/beit-base-patch16-224": 85761984,
        "microsoft/beit-large-patch16-512": 304649728,
        "facebook/deit-base-patch16-384": 86090496,
        "microsoft/cvt-21-384-22k": 31237696,
        "microsoft/cvt-13": 19612480,
        "google/vit-large-patch16-224": 303301632,
        "google/vit-base-patch16-384": 86090496,
        "apple/mobilevit-xx-small": 951024,
        "facebook/deit-base-patch16-224": 85798656,
        "facebook/deit-small-patch16-224": 21665664,
        "facebook/deit-tiny-patch16-224": 5524416,
    },
    "renggli": {
        30000: {
            "microsoft/swinv2-base-patch4-window8-256": 0.946969696969697,
            "Intel/vit-base-patch16-224-int8-static": 0.15854978354978355,
            "microsoft/swin-base-patch4-window12-384": 0.9680735930735932,
            "facebook/dinov2-base-imagenet1k-1-layer": 0.9626623376623376,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.9426406926406926,
            "microsoft/swin-large-patch4-window12-384-in22k": 0.9621212121212122,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.9545454545454546,
            "microsoft/beit-base-patch16-224": 0.9588744588744588,
            "microsoft/beit-large-patch16-512": 0.9772727272727272,
            "facebook/deit-base-patch16-384": 0.9415584415584416,
            "microsoft/cvt-21-384-22k": 0.954004329004329,
            "microsoft/cvt-13": 0.9366883116883116,
            "google/vit-large-patch16-224": 0.9431818181818182,
            "google/vit-base-patch16-384": 0.95508658008658,
            "apple/mobilevit-xx-small": 0.8982683982683982,
            "apple/mobilevit-small": 0.9388528138528138,
            "facebook/deit-base-patch16-224": 0.9345238095238096,
            "facebook/deit-small-patch16-224": 0.91504329004329,
            "facebook/deit-tiny-patch16-224": 0.8825757575757576,
        },
        15000: {
            "microsoft/swinv2-base-patch4-window8-256": 0.946969696969697,
            "Intel/vit-base-patch16-224-int8-static": 0.1423160173160173,
            "microsoft/swin-base-patch4-window12-384": 0.9680735930735932,
            "facebook/dinov2-base-imagenet1k-1-layer": 0.9626623376623376,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.9426406926406926,
            "microsoft/swin-large-patch4-window12-384-in22k": 0.9621212121212122,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.9545454545454546,
            "microsoft/beit-base-patch16-224": 0.9588744588744588,
            "microsoft/beit-large-patch16-512": 0.9772727272727272,
            "facebook/deit-base-patch16-384": 0.9415584415584416,
            "microsoft/cvt-21-384-22k": 0.954004329004329,
            "microsoft/cvt-13": 0.9366883116883116,
            "google/vit-large-patch16-224": 0.9431818181818182,
            "google/vit-base-patch16-384": 0.95508658008658,
            "apple/mobilevit-xx-small": 0.8982683982683982,
            "apple/mobilevit-small": 0.9388528138528138,
            "facebook/deit-base-patch16-224": 0.9345238095238096,
            "facebook/deit-small-patch16-224": 0.91504329004329,
            "facebook/deit-tiny-patch16-224": 0.8825757575757576,
        },
        10000: {
            "microsoft/swinv2-base-patch4-window8-256": 0.946969696969697,
            "Intel/vit-base-patch16-224-int8-static": 0.1488095238095238,
            "microsoft/swin-base-patch4-window12-384": 0.9680735930735932,
            "facebook/dinov2-base-imagenet1k-1-layer": 0.9626623376623376,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.9426406926406926,
            "microsoft/swin-large-patch4-window12-384-in22k": 0.9621212121212122,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.9545454545454546,
            "microsoft/beit-base-patch16-224": 0.9588744588744588,
            "microsoft/beit-large-patch16-512": 0.9772727272727272,
            "facebook/deit-base-patch16-384": 0.9415584415584416,
            "microsoft/cvt-21-384-22k": 0.954004329004329,
            "microsoft/cvt-13": 0.9366883116883116,
            "google/vit-large-patch16-224": 0.9431818181818182,
            "google/vit-base-patch16-384": 0.95508658008658,
            "apple/mobilevit-xx-small": 0.8982683982683982,
            "apple/mobilevit-small": 0.9388528138528138,
            "facebook/deit-base-patch16-224": 0.9345238095238096,
            "facebook/deit-small-patch16-224": 0.91504329004329,
            "facebook/deit-tiny-patch16-224": 0.8825757575757576,
        },
        1000: {
            "microsoft/swinv2-base-patch4-window8-256": 0.944,
            "Intel/vit-base-patch16-224-int8-static": 0.108,
            "microsoft/swin-base-patch4-window12-384": 0.952,
            "facebook/dinov2-base-imagenet1k-1-layer": 0.952,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.94,
            "microsoft/swin-large-patch4-window12-384-in22k": 0.944,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.928,
            "microsoft/beit-base-patch16-224": 0.928,
            "microsoft/beit-large-patch16-512": 0.976,
            "facebook/deit-base-patch16-384": 0.924,
            "microsoft/cvt-21-384-22k": 0.92,
            "microsoft/cvt-13": 0.916,
            "google/vit-large-patch16-224": 0.928,
            "google/vit-base-patch16-384": 0.948,
            "apple/mobilevit-xx-small": 0.86,
            "apple/mobilevit-small": 0.948,
            "facebook/deit-base-patch16-224": 0.924,
            "facebook/deit-small-patch16-224": 0.892,
            "facebook/deit-tiny-patch16-224": 0.896,
        },
        500: {
            "apple/mobilevit-small": 0.888,
            "microsoft/swinv2-base-patch4-window8-256": 0.92,
            "Intel/vit-base-patch16-224-int8-static": 0.08,
            "microsoft/swin-base-patch4-window12-384": 0.92,
            "facebook/dinov2-base-imagenet1k-1-layer": 0.872,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.872,
            "microsoft/swin-large-patch4-window12-384-in22k": 0.896,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.912,
            "microsoft/beit-base-patch16-224": 0.936,
            "microsoft/beit-large-patch16-512": 0.928,
            "facebook/deit-base-patch16-384": 0.872,
            "microsoft/cvt-21-384-22k": 0.864,
            "microsoft/cvt-13": 0.92,
            "google/vit-large-patch16-224": 0.864,
            "google/vit-base-patch16-384": 0.904,
            "apple/mobilevit-xx-small": 0.872,
            "facebook/deit-base-patch16-224": 0.864,
            "facebook/deit-small-patch16-224": 0.864,
            "facebook/deit-tiny-patch16-224": 0.784,
        },
    },
    "logme": {
        30000: {
            "microsoft/swinv2-base-patch4-window8-256": 1.3728822025675995,
            "Intel/vit-base-patch16-224-int8-static": 0.4088116067248125,
            "microsoft/swin-base-patch4-window12-384": 1.3224352589076112,
            "facebook/dinov2-base-imagenet1k-1-layer": 1.2059217138960283,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.8987515791544146,
            "microsoft/swin-large-patch4-window12-384-in22k": 1.222286643088904,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 1.0756677502808007,
            "microsoft/beit-base-patch16-224": 1.271444823102752,
            "microsoft/beit-large-patch16-512": 1.525679057511812,
            "facebook/deit-base-patch16-384": 1.1345133045985123,
            "microsoft/cvt-21-384-22k": 1.0965178931463235,
            "microsoft/cvt-13": 1.1209526643486478,
            "google/vit-large-patch16-224": 1.232285211275284,
            "google/vit-base-patch16-384": 1.2584118668727,
            "apple/mobilevit-xx-small": 0.8947857695325044,
            "apple/mobilevit-small": 1.1391954855233268,
            "facebook/deit-base-patch16-224": 1.0985066945602708,
            "facebook/deit-small-patch16-224": 0.9567092074768188,
            "facebook/deit-tiny-patch16-224": 0.7307845341321054,
        },
        15000: {
            "microsoft/swinv2-base-patch4-window8-256": 1.3728822025675995,
            "Intel/vit-base-patch16-224-int8-static": 0.4092706948074233,
            "microsoft/swin-base-patch4-window12-384": 1.3224352589076112,
            "facebook/dinov2-base-imagenet1k-1-layer": 1.2059217138960283,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.8987515791544146,
            "microsoft/swin-large-patch4-window12-384-in22k": 1.222286643088904,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 1.0756677502808007,
            "microsoft/beit-base-patch16-224": 1.271444823102752,
            "microsoft/beit-large-patch16-512": 1.525679057511812,
            "facebook/deit-base-patch16-384": 1.1345133045985123,
            "microsoft/cvt-21-384-22k": 1.0965178931463235,
            "microsoft/cvt-13": 1.1209526643486478,
            "google/vit-large-patch16-224": 1.232285211275284,
            "google/vit-base-patch16-384": 1.2584118668727,
            "apple/mobilevit-xx-small": 0.8947857695325044,
            "apple/mobilevit-small": 1.1391954855233268,
            "facebook/deit-base-patch16-224": 1.0985066945602708,
            "facebook/deit-small-patch16-224": 0.9567092074768188,
            "facebook/deit-tiny-patch16-224": 0.7307845341321054,
        },
        10000: {
            "microsoft/swinv2-base-patch4-window8-256": 1.3728822025675995,
            "Intel/vit-base-patch16-224-int8-static": 0.4094828153332859,
            "microsoft/swin-base-patch4-window12-384": 1.3224352589076112,
            "facebook/dinov2-base-imagenet1k-1-layer": 1.2059217138960283,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.8987515791544146,
            "microsoft/swin-large-patch4-window12-384-in22k": 1.222286643088904,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 1.0756677502808007,
            "microsoft/beit-base-patch16-224": 1.271444823102752,
            "microsoft/beit-large-patch16-512": 1.525679057511812,
            "facebook/deit-base-patch16-384": 1.1345133045985123,
            "microsoft/cvt-21-384-22k": 1.0965178931463235,
            "microsoft/cvt-13": 1.1209526643486478,
            "google/vit-large-patch16-224": 1.232285211275284,
            "google/vit-base-patch16-384": 1.2584118668727,
            "apple/mobilevit-xx-small": 0.8947857695325044,
            "apple/mobilevit-small": 1.1391954855233268,
            "facebook/deit-base-patch16-224": 1.0985066945602708,
            "facebook/deit-small-patch16-224": 0.9567092074768188,
            "facebook/deit-tiny-patch16-224": 0.7307845341321054,
        },
        1000: {
            "microsoft/swinv2-base-patch4-window8-256": 1.3118932132876542,
            "Intel/vit-base-patch16-224-int8-static": 0.40459621798811735,
            "microsoft/swin-base-patch4-window12-384": 1.240316351243088,
            "facebook/dinov2-base-imagenet1k-1-layer": 4.1922308581114125,
            "facebook/dinov2-small-imagenet1k-1-layer": 0.7426657673505446,
            "microsoft/swin-large-patch4-window12-384-in22k": 3.565565868388461,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 0.8979105726489505,
            "microsoft/beit-base-patch16-224": 1.102391328642817,
            "microsoft/beit-large-patch16-512": 1.4746100661557642,
            "facebook/deit-base-patch16-384": 0.9625745151279862,
            "microsoft/cvt-21-384-22k": 0.9503068171721626,
            "microsoft/cvt-13": 0.994080005467833,
            "google/vit-large-patch16-224": 1.1877245144196449,
            "google/vit-base-patch16-384": 1.085262417533064,
            "apple/mobilevit-xx-small": 0.777685185962693,
            "apple/mobilevit-small": 0.970288044139028,
            "facebook/deit-base-patch16-224": 0.9361809540527316,
            "facebook/deit-small-patch16-224": 0.8358766060748263,
            "facebook/deit-tiny-patch16-224": 0.6597211998782025,
        },
        500: {
            "apple/mobilevit-small": 1.8296683442816464,
            "microsoft/swinv2-base-patch4-window8-256": 5.505130999101676,
            "Intel/vit-base-patch16-224-int8-static": 3.354538990358462,
            "microsoft/swin-base-patch4-window12-384": 5.886628195618854,
            "facebook/dinov2-base-imagenet1k-1-layer": 12.933042685371293,
            "facebook/dinov2-small-imagenet1k-1-layer": 3.847551428268824,
            "microsoft/swin-large-patch4-window12-384-in22k": 10.569438270006732,
            "microsoft/beit-base-patch16-224-pt22k-ft22k": 3.4793629003522866,
            "microsoft/beit-base-patch16-224": 3.9618372572234457,
            "microsoft/beit-large-patch16-512": 7.178723398906834,
            "facebook/deit-base-patch16-384": 3.3330459385547657,
            "microsoft/cvt-21-384-22k": 0.8789794289039958,
            "microsoft/cvt-13": 0.9400804915270818,
            "google/vit-large-patch16-224": 6.322992370665466,
            "google/vit-base-patch16-384": 3.767158102356334,
            "apple/mobilevit-xx-small": 0.7089872369101843,
            "facebook/deit-base-patch16-224": 3.329425341090949,
            "facebook/deit-small-patch16-224": 0.7778209764199684,
            "facebook/deit-tiny-patch16-224": 0.6195115071444163,
        },
    },
}

# %%
metric_scores.keys()
# Out:
# dict_keys(['n_pars', 'renggli', 'logme'])

# %%
len(metric_scores["n_pars"].keys())
# Out:
# 19

# %%
plt.scatter(list(metric_scores["n_pars"].values()), list(val_acc.values()))

# %%
n_pars = []
acc_vals = []
for model in val_acc.keys():
    n_pars.append(metric_scores["n_pars"][model])
    acc_vals.append(val_acc[model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(acc_vals, n_pars)
ax.set_xlabel("validation_accuracy")
ax.set_ylabel("model parameters")
fig.suptitle("Parameter Count vs. Validation Accuracy on Oxford Pets")
# Out:
# Text(0.5, 0.98, 'Parameter Count vs. Validation Accuracy on Oxfor Pets')

# %%
# remove low validation accuracy outliers
n_pars = []
acc_vals = []
for model in val_acc.keys():
    if val_acc[model] < 0.5:
        continue
    n_pars.append(metric_scores["n_pars"][model])
    acc_vals.append(val_acc[model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(acc_vals, n_pars)
ax.set_xlabel("validation_accuracy")
ax.set_ylabel("model parameters")
fig.suptitle("Parameter Count vs. Validation Accuracy on Oxford Pets")
# Out:
# Text(0.5, 0.98, 'Parameter Count vs. Validation Accuracy on Oxford Pets')

# %%
def plot(metric, n_samples=None, remove_outliers=False):
    """Plot validation accuracy vs. metric scores, with or without outlier"""
    m_scores = []
    v_acc = []
    for model in val_acc.keys():
        if remove_outliers:
            if val_acc[model] < 0.5:
                continue

        v_acc.append(val_acc[model])

        if n_samples is not None:
            m_scores.append(metric_scores[metric][n_samples][model])
        else:
            m_scores.append(metric_scores[metric][model])

    x = np.linspace(0.86, 0.985, 10000)
    y = x

    fig, ax = plt.subplots(1)
    ax.scatter(m_scores, v_acc)
    ax.plot(x, y)
    ax.set_ylabel("validation_accuracy")
    ax.set_xlabel(f"{metric} score")

    title = f"Val Acc vs. {metric} score"
    if n_samples is not None:
        title += f" {n_samples} samples"
    if remove_outliers:
        title += " no outliers"

    fig.suptitle(title)

    plt.show()

# %%
plot("renggli", n_samples=30000, remove_outliers=True)

# %%
r_scores = []
val_scores = []
for model in val_acc.keys():
    if val_acc[model] < 0.5:
        continue
    r_scores.append(metric_scores["renggli"][30000][model])
    val_scores.append(val_acc[model] - metric_scores["renggli"][30000][model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(r_scores, val_scores)
ax.set_ylabel("validation_accuracy - renggli")
ax.set_xlabel("renggli score")
# Out:
# Text(0.5, 0, 'renggli score')

# %% [markdown]
# Plot ranking by validation and by metric score

# %%
sorted_val_acc = {
    k: v for k, v in sorted(val_acc.items(), key=lambda item: item[1], reverse=True)
}

# %%
sorted_n_pars = {
    k: v
    for k, v in sorted(
        metric_scores["n_pars"].items(), key=lambda item: item[1], reverse=True
    )
}

# %%
n_par_rank = {k: idx + 1 for idx, k in enumerate(sorted_n_pars.keys())}

# %%
n_par_rank
# Out:
# {'microsoft/beit-large-patch16-512': 1,
#  'google/vit-large-patch16-224': 2,
#  'microsoft/swin-large-patch4-window12-384-in22k': 3,
#  'microsoft/swinv2-base-patch4-window8-256': 4,
#  'microsoft/swin-base-patch4-window12-384': 5,
#  'facebook/dinov2-base-imagenet1k-1-layer': 6,
#  'facebook/deit-base-patch16-384': 7,
#  'google/vit-base-patch16-384': 8,
#  'Intel/vit-base-patch16-224-int8-static': 9,
#  'facebook/deit-base-patch16-224': 10,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 11,
#  'microsoft/beit-base-patch16-224': 12,
#  'microsoft/cvt-21-384-22k': 13,
#  'facebook/dinov2-small-imagenet1k-1-layer': 14,
#  'facebook/deit-small-patch16-224': 15,
#  'microsoft/cvt-13': 16,
#  'facebook/deit-tiny-patch16-224': 17,
#  'apple/mobilevit-small': 18,
#  'apple/mobilevit-xx-small': 19}

# %%
val_acc_rank = {k: idx + 1 for idx, k in enumerate(sorted_val_acc.keys())}

# %%
n_scores = []
v_scores = []
for model in val_acc_rank.keys():
    if val_acc[model] < 0.5:
        continue
    n_scores.append(n_par_rank[model])
    v_scores.append(val_acc_rank[model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(n_scores, v_scores)
ax.set_xlabel("n_pars rank")
ax.set_ylabel("validation acc rank")
# Out:
# Text(0, 0.5, 'validation acc rank')

# %%
sorted_renggli = {
    k: v
    for k, v in sorted(
        metric_scores["renggli"][30000].items(), key=lambda item: item[1], reverse=True
    )
}

# %%
renggli_rank = {k: idx + 1 for idx, k in enumerate(sorted_renggli.keys())}

# %%
renggli_rank
# Out:
# {'microsoft/beit-large-patch16-512': 1,
#  'microsoft/swin-base-patch4-window12-384': 2,
#  'facebook/dinov2-base-imagenet1k-1-layer': 3,
#  'microsoft/swin-large-patch4-window12-384-in22k': 4,
#  'microsoft/beit-base-patch16-224': 5,
#  'google/vit-base-patch16-384': 6,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 7,
#  'microsoft/cvt-21-384-22k': 8,
#  'microsoft/swinv2-base-patch4-window8-256': 9,
#  'google/vit-large-patch16-224': 10,
#  'facebook/dinov2-small-imagenet1k-1-layer': 11,
#  'facebook/deit-base-patch16-384': 12,
#  'apple/mobilevit-small': 13,
#  'microsoft/cvt-13': 14,
#  'facebook/deit-base-patch16-224': 15,
#  'facebook/deit-small-patch16-224': 16,
#  'apple/mobilevit-xx-small': 17,
#  'facebook/deit-tiny-patch16-224': 18,
#  'Intel/vit-base-patch16-224-int8-static': 19}

# %%
r_scores = []
v_scores = []
for model in val_acc_rank.keys():
    if val_acc[model] < 0.5:
        continue
    r_scores.append(renggli_rank[model])
    v_scores.append(val_acc_rank[model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(r_scores, v_scores)
ax.set_xlabel("renggli rank")
ax.set_ylabel("validation acc rank")
# Out:
# Text(0, 0.5, 'validation acc rank')

# %%
sorted_logme = {
    k: v
    for k, v in sorted(
        metric_scores["logme"][30000].items(), key=lambda item: item[1], reverse=True
    )
}

# %%
logme_rank = {k: idx + 1 for idx, k in enumerate(sorted_logme.keys())}

# %%
l_scores = []
v_scores = []
for model in val_acc_rank.keys():
    if val_acc[model] < 0.5:
        continue
    l_scores.append(logme_rank[model])
    v_scores.append(val_acc_rank[model])

# %%
fig, ax = plt.subplots(1)
ax.scatter(l_scores, v_scores)
ax.set_xlabel("logme rank")
ax.set_ylabel("validation acc rank")
# Out:
# Text(0, 0.5, 'validation acc rank')

# %% [markdown]
# ## And now to do this properly by pulling data directly from wandb

# %%
import wandb

api = wandb.Api()

# %%
# import top level config
with open("../configs/top_config_second_run.yaml", "r") as f:
    t_config = yaml.safe_load(f)

# %%
t_config["wandb"]
# Out:
# {'entity': 'turing-arc', 'project': 'locomoset', 'log_model': 'checkpoint'}

# %%
run = api.run(f"{t_config['wandb']['entity']}/{t_config['wandb']['project']}/e7l2mbpp")

# %%
run.history()["metric_scores.LogME.score"]
# Out:
# 0    1.372882
# Name: metric_scores.LogME.score, dtype: float64

# %% [markdown]
# Ok, change of pace, connecting to the API like above won't work, so here is the code to download the whole thing at once...

# %%
import pandas as pd
import wandb

api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("turing-arc/locomoset")

summary_list, config_list, name_list = [], [], []
for run in runs:
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

runs_df = pd.DataFrame(
    {"summary": summary_list, "config": config_list, "name": name_list}
)

runs_df.to_csv("project.csv")

# %%
runs_df
# Out:
#                                                summary  \
# 0    {'eval/runtime': 673.0549, 'eval/steps_per_sec...
# 1    {'train/epoch': 1.2, 'train/learning_rate': 4....
# 2    {'train/train_loss': 0.23577865063051331, 'eva...
# 3    {'train/train_loss': 0.2530900898124611, 'trai...
# 4    {'train/total_flos': 5.07252557837117e+19, '_s...
# ..                                                 ...
# 564  {'_runtime': 19.16059160232544, 'dataset_name'...
# 565  {'random_state': 42, 'dataset_split': 'train',...
# 566  {'model_name': 'facebook/deit-base-distilled-p...
# 567  {'local_save': None, 'random_state': 42, 'data...
# 568  {'_wandb': {'runtime': 78}, 'local_save': None...
#
#                                                 config  \
# 0    {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 1    {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 2    {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 3    {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# ...

# %%
pets_df = runs_df[runs_df.name.str.match("pcuenq-oxford-pets.*")]

# %%
pets_df
# Out:
#                                                summary  \
# 223  {'_step': 98, 'train/global_step': 6930, 'eval...
# 224  {'eval/samples_per_second': 64.804, '_step': 9...
# 225  {'eval/runtime': 49.2001, 'train/train_loss': ...
# 226  {'train/train_loss': 2.5912876652088688, 'eval...
# 227  {'train/train_runtime': 7570.0305, '_wandb': {...
# ..                                                 ...
# 564  {'_runtime': 19.16059160232544, 'dataset_name'...
# 565  {'random_state': 42, 'dataset_split': 'train',...
# 566  {'model_name': 'facebook/deit-base-distilled-p...
# 567  {'local_save': None, 'random_state': 42, 'data...
# 568  {'_wandb': {'runtime': 78}, 'local_save': None...
#
#                                                 config  \
# 223  {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 224  {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 225  {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# 226  {'bf16': False, 'fp16': False, 'fsdp': [], 'se...
# ...

# %%
useful_results = []

for row in pets_df["summary"]:
    if row.get("wandb_args") is not None:
        if row["wandb_args"]["job_type"] == "metrics":
            useful_results.append(row)

# %%
useful_results[-1]
# Out:
# {'_wandb': {'runtime': 78},
#  'local_save': None,
#  'wandb_args': {'entity': 'turing-arc',
#   'project': 'locomoset',
#   'job_type': 'metrics'},
#  'dataset_name': 'pcuenq/oxford-pets',
#  'dataset_split': 'train',
#  'metric_scores': {'n_pars': {'time': 0.0006997585296630859,
#    'score': 85800192},
#   'renggli': {'time': 0.8726389408111572, 'score': 0.896},
#   'LogME': {'time': 0.13429808616638184, 'score': 3.666199312287823}},
#  'inference_times': {'model': 1.2181129455566406,
#   'features': 27.027297019958496},
#  '_step': 0,
#  '_runtime': 79.01255345344543,
#  'n_samples': 500,
#  '_timestamp': 1699447263.2474356,
#  'config_gen_dtime': '20231108-120520-157889',
#  'metrics': ['renggli', 'n_pars', 'LogME'],
#  'run_name': 'pcuenq-oxford-pets_facebook-deit-base-distilled-patch16-224',
#  'save_dir': 'results_pets',
#  'use_wandb': True,
#  'model_name': 'facebook/deit-base-distilled-patch16-224',
#  'random_state': 42,
# ...

# %%
metric_results = {}
for res in useful_results:
    for met in res["metric_scores"].keys():
        if metric_results.get(met) is not None:
            if met == "n_pars":
                metric_results[met][res["model_name"]] = res["metric_scores"][met][
                    "score"
                ]
            else:
                if metric_results[met].get(res["n_samples"]) is not None:
                    metric_results[met][res["n_samples"]][res["model_name"]] = res[
                        "metric_scores"
                    ][met]["score"]
                else:
                    metric_results[met][res["n_samples"]] = {}
                    metric_results[met][res["n_samples"]][res["model_name"]] = res[
                        "metric_scores"
                    ][met]["score"]
        else:
            metric_results[met] = {}
            if met == "n_pars":
                metric_results[met][res["model_name"]] = res["metric_scores"][met][
                    "score"
                ]
            else:
                if metric_results[met].get(res["n_samples"]) is not None:
                    metric_results[met][res["n_samples"]][res["model_name"]] = res[
                        "metric_scores"
                    ][met]["score"]
                else:
                    metric_results[met][res["n_samples"]] = {}
                    metric_results[met][res["n_samples"]][res["model_name"]] = res[
                        "metric_scores"
                    ][met]["score"]

# %%
with open("metric_results_pets.yaml", "w") as f:
    yaml.safe_dump(metric_results, f)

# %% [markdown]
# Ok so that's how to get the metric scores to work, lets get the training accuracy for pets

# %%
x = 0
for row in pets_df.config:
    if row.get("locomoset") is not None:
        x += 1

print(x)
# Out:
# 346

# %%
train_res = []

for index, row in pets_df.iterrows():
    if row["config"]["locomoset"]["wandb_args"]["job_type"] == "train":
        train_res.append((row["config"]["locomoset"]["model_name"], row["summary"]))

# %%
train_res = {}

for index, row in pets_df.iterrows():
    if row["config"]["locomoset"]["wandb_args"]["job_type"] == "train":
        if row["summary"].get("eval/accuracy") is not None:
            train_res[row["config"]["locomoset"]["model_name"]] = row["summary"].get(
                "eval/accuracy"
            )

# %%
train_res
# Out:
# {'microsoft/swinv2-base-patch4-window8-256': 0.961038961038961,
#  'Intel/vit-base-patch16-224-int8-static': 0.21645021645021645,
#  'microsoft/swin-base-patch4-window12-384': 0.9653679653679652,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.283008658008658,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.9637445887445888,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.3327922077922078,
#  'microsoft/beit-base-patch16-224': 0.9496753246753248,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.9453463203463204,
#  'microsoft/beit-large-patch16-512': 0.966991341991342,
#  'facebook/deit-base-patch16-384': 0.9577922077922078,
#  'microsoft/cvt-21-384-22k': 0.9561688311688312,
#  'microsoft/cvt-13': 0.9491341991341992,
#  'google/vit-large-patch16-224': 0.9264069264069263,
#  'google/vit-base-patch16-384': 0.9583333333333334,
#  'facebook/deit-base-patch16-224': 0.948051948051948,
#  'apple/mobilevit-xx-small': 0.8576839826839827,
# ...

# %% [markdown]
# Ok, so the above works to pull out the data, now just to turn it into a rudimentary pipeline for making graphs etc.

# %% [markdown]
# but first a slightly cleverer way to use the api:

# %%
import pandas as pd
import wandb

api = wandb.Api()

# Project is specified by <entity/project-name>
train_runs = api.runs(
    path="turing-arc/locomoset",
    filters={"group": "pcuenq/oxford-pets_20231110-083306-254553", "jobType": "train"},
)

metric_runs = api.runs(
    path="turing-arc/locomoset",
    filters={
        "group": "pcuenq/oxford-pets_20231110-083306-254553",
        "jobType": "metrics",
    },
)

summary_train, config_train, name_train = [], [], []
for run in train_runs:
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files
    summary_train.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_train.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_train.append(run.name)

train_df = pd.DataFrame(
    {"summary": summary_train, "config": config_train, "name": name_train}
)

summary_metrics, config_metrics, name_metrics = [], [], []
for run in metric_runs:
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files
    summary_metrics.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_metrics.append(
        {k: v for k, v in run.config.items() if not k.startswith("_")}
    )

    # .name is the human-readable name of the run.
    name_metrics.append(run.name)

metrics_df = pd.DataFrame(
    {"summary": summary_metrics, "config": config_metrics, "name": name_metrics}
)

# runs_df.to_csv("project.csv")

# %%
train_res = {}

for _, row in train_df.iterrows():
    if row.summary.get("eval/accuracy") is not None:
        train_res[row.config["locomoset"].get("model_name")] = row.summary.get(
            "eval/accuracy"
        )

# %%
train_res
# Out:
# {'microsoft/swinv2-base-patch4-window8-256': 0.961038961038961,
#  'Intel/vit-base-patch16-224-int8-static': 0.21645021645021645,
#  'microsoft/swin-base-patch4-window12-384': 0.9653679653679652,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.25,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.9659090909090908,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.29004329004329005,
#  'microsoft/beit-base-patch16-224': 0.9453463203463204,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.941017316017316,
#  'microsoft/beit-large-patch16-512': 0.9675324675324676,
#  'facebook/deit-base-patch16-384': 0.9648268398268398,
#  'microsoft/cvt-21-384-22k': 0.9518398268398268,
#  'microsoft/cvt-13': 0.9567099567099568,
#  'google/vit-large-patch16-224': 0.9437229437229436,
#  'google/vit-base-patch16-384': 0.9594155844155844,
#  'facebook/deit-base-patch16-224': 0.9475108225108224,
#  'apple/mobilevit-xx-small': 0.8679653679653679,
#  'apple/mobilevit-small': 0.9442640692640693,
# ...

# %%
metric_results = {}

for _, row in metrics_df.iterrows():
    for met in row.summary["metric_scores"].keys():
        if metric_results.get(met) is not None:
            if met == "n_pars":
                metric_results[met][row.summary["model_name"]] = row.summary[
                    "metric_scores"
                ][met]["score"]
            else:
                if metric_results[met].get(row.summary["n_samples"]) is not None:
                    metric_results[met][row.summary["n_samples"]][
                        row.summary["model_name"]
                    ] = row.summary["metric_scores"][met]["score"]
                else:
                    metric_results[met][row.summary["n_samples"]] = {}
                    metric_results[met][row.summary["n_samples"]][
                        row.summary["model_name"]
                    ] = row.summary["metric_scores"][met]["score"]
        else:
            metric_results[met] = {}
            if met == "n_pars":
                metric_results[met][row.summary["model_name"]] = row.summary[
                    "metric_scores"
                ][met]["score"]
            else:
                if metric_results[met].get(row.summary["n_samples"]) is not None:
                    metric_results[met][row.summary["n_samples"]][
                        row.summary["model_name"]
                    ] = row.summary["metric_scores"][met]["score"]
                else:
                    metric_results[met][row.summary["n_samples"]] = {}
                    metric_results[met][row.summary["n_samples"]][
                        row.summary["model_name"]
                    ] = row.summary["metric_scores"][met]["score"]

# %% [markdown]
# Ok, so now lets tie to together into a function that spits out the validation scores and the metric results given a group name from wandb

# %% [markdown]
# ...maybe a coffee first....

# %%
import pandas as pd
import wandb


def pull_metric_and_train_data(group_name: str):
    """Pull metric and train data from weights and biases, turning it into the requisite
    dict structure for the plotting functions above"""

    api = wandb.Api()

    # Project is specified by <entity/project-name>
    train_runs = api.runs(
        path="turing-arc/locomoset",
        filters={"group": group_name, "jobType": "train"},
    )

    summary_train, config_train, name_train = [], [], []
    for run in train_runs:
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        summary_train.append(run.summary._json_dict)

        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        config_train.append(
            {k: v for k, v in run.config.items() if not k.startswith("_")}
        )

        # .name is the human-readable name of the run.
        name_train.append(run.name)

    train_df = pd.DataFrame(
        {"summary": summary_train, "config": config_train, "name": name_train}
    )

    train_res = {}

    for _, row in train_df.iterrows():
        if row.summary.get("eval/accuracy") is not None:
            train_res[row.config["locomoset"].get("model_name")] = row.summary.get(
                "eval/accuracy"
            )

    metric_runs = api.runs(
        path="turing-arc/locomoset",
        filters={
            "group": group_name,
            "jobType": "metrics",
        },
    )

    summary_metrics, config_metrics, name_metrics = [], [], []
    for run in metric_runs:
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        summary_metrics.append(run.summary._json_dict)

        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        config_metrics.append(
            {k: v for k, v in run.config.items() if not k.startswith("_")}
        )

        # .name is the human-readable name of the run.
        name_metrics.append(run.name)

    metrics_df = pd.DataFrame(
        {"summary": summary_metrics, "config": config_metrics, "name": name_metrics}
    )

    metric_results = {}

    for _, row in metrics_df.iterrows():
        for met in row.summary["metric_scores"].keys():
            if metric_results.get(met) is not None:
                if met == "n_pars":
                    metric_results[met][row.summary["model_name"]] = row.summary[
                        "metric_scores"
                    ][met]["score"]
                else:
                    if metric_results[met].get(row.summary["n_samples"]) is not None:
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
                    else:
                        metric_results[met][row.summary["n_samples"]] = {}
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
            else:
                metric_results[met] = {}
                if met == "n_pars":
                    metric_results[met][row.summary["model_name"]] = row.summary[
                        "metric_scores"
                    ][met]["score"]
                else:
                    if metric_results[met].get(row.summary["n_samples"]) is not None:
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
                    else:
                        metric_results[met][row.summary["n_samples"]] = {}
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]

    return train_res, metric_results

# %%
tres, mres = pull_metric_and_train_data("pcuenq/oxford-pets_20231110-083306-254553")

# %% [markdown]
# And now a new plotting function:

# %%
from scipy.stats import spearmanr

# %%
def plotter(
    val_acc: dict,
    metric_scores: dict,
    metric: str,
    n_samples: int | None = None,
    remove_outliers: bool = False,
    outlier_threshold: float = 0.5,
    ranked: bool = False,
    xy: bool = False,
    dataset_name: str | None = None,
):
    """Plot validation accuracy vs. metric scores, with or without outlier, with ranking or not"""
    # if metric == "n_pars":
    #     n_samples = None
    # else:
    #     if n_samples is None:
    #         n_samples = 30000

    if ranked:
        sorted_val_acc = {
            k: v
            for k, v in sorted(val_acc.items(), key=lambda item: item[1], reverse=True)
        }
        if remove_outliers:
            for model in val_acc.keys():
                if val_acc[model] < outlier_threshold:
                    sorted_val_acc.pop(model)
            new_sorted_val_acc = {
                k: v
                for k, v in sorted(
                    sorted_val_acc.items(), key=lambda item: item[1], reverse=True
                )
            }
            sorted_val_acc = new_sorted_val_acc
        v_rank = {k: idx + 1 for idx, k in enumerate(sorted_val_acc.keys())}
        # print(v_rank)

        if n_samples is not None:
            sorted_met = {
                k: v
                for k, v in sorted(
                    metric_scores[metric][n_samples].items(),
                    key=lambda item: item[1],
                    reverse=True,
                )
            }
        else:
            sorted_met = {
                k: v
                for k, v in sorted(
                    metric_scores[metric].items(),
                    key=lambda item: item[1],
                    reverse=True,
                )
            }
        if remove_outliers:
            for model in val_acc.keys():
                if val_acc[model] < outlier_threshold:
                    sorted_met.pop(model)
            new_sorted_met = {
                k: v
                for k, v in sorted(
                    sorted_met.items(), key=lambda item: item[1], reverse=True
                )
            }
            sorted_met = new_sorted_met
        m_rank = {k: idx + 1 for idx, k in enumerate(sorted_met.keys())}
        # print(m_rank)

        m_scores = []
        v_acc = []
        for model in v_rank.keys():
            m_scores.append(m_rank[model])
            v_acc.append(v_rank[model])
        # print(m_scores)
        # print(v_acc)

    else:
        m_scores = []
        v_acc = []
        for model in val_acc.keys():
            if remove_outliers:
                if val_acc[model] < outlier_threshold:
                    continue

            v_acc.append(val_acc[model])

            if n_samples is not None:
                m_scores.append(metric_scores[metric][n_samples][model])
            else:
                m_scores.append(metric_scores[metric][model])

    fig, ax = plt.subplots(1)
    ax.scatter(m_scores, v_acc)
    corr = np.round(spearmanr(m_scores, v_acc)[0], 2)

    if ranked:
        ax.set_ylabel("validation accuracy ranking")
        ax.set_xlabel(f"{metric} score ranking")
    else:
        ax.set_ylabel("validation accuracy")
        ax.set_xlabel(f"{metric} score")

    if xy:
        x = np.linspace(
            min(min(m_scores), min(v_acc)), max(max(m_scores), max(v_acc)), 10000
        )
        y = x
        ax.plot(x, y)

    title = f"Val Acc vs. {metric} score, correlation: {corr}"
    if dataset_name is not None:
        title = dataset_name + "; " + title
    if n_samples is not None:
        title += f", {n_samples} samples"
    if remove_outliers:
        title += ", no outliers"
    if ranked:
        title += ", ranked"

    fig.suptitle(title)

    plt.show()

# %%
plotter(
    val_acc=tres,
    metric_scores=mres,
    metric="LogME",
    n_samples=15000,
    remove_outliers=False,
    ranked=False,
    xy=False,
)

# %% [markdown]
# Ok Time to use the above to create some graphs for the presentation:

# %% [markdown]
# ### Pets Graphs

# %%
pets_tres, pets_mres = pull_metric_and_train_data(
    "pcuenq/oxford-pets_20231110-083306-254553"
)

# %%
pets_var = np.var(list(pets_tres.values()))
pets_var
# Out:
# 0.06467393070488728

# %%
pets_mean = np.mean(list(pets_tres.values()))
pets_mean
# Out:
# 0.836637047163363

# %%
pets_tres_no_outliers = {
    k: v for k, v in pets_tres.items() if v > pets_mean - 3 * pets_var
}

# %%
max(pets_tres_no_outliers.values())
# Out:
# 0.9675324675324676

# %%
len(pets_tres_no_outliers.keys())
# Out:
# 16

# %%
pets_tres
# Out:
# {'microsoft/swinv2-base-patch4-window8-256': 0.961038961038961,
#  'Intel/vit-base-patch16-224-int8-static': 0.21645021645021645,
#  'microsoft/swin-base-patch4-window12-384': 0.9653679653679652,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.25,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.9659090909090908,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.29004329004329005,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.941017316017316,
#  'microsoft/beit-base-patch16-224': 0.9453463203463204,
#  'microsoft/beit-large-patch16-512': 0.9675324675324676,
#  'facebook/deit-base-patch16-384': 0.9648268398268398,
#  'microsoft/cvt-21-384-22k': 0.9518398268398268,
#  'microsoft/cvt-13': 0.9567099567099568,
#  'google/vit-large-patch16-224': 0.9437229437229436,
#  'google/vit-base-patch16-384': 0.9594155844155844,
#  'facebook/deit-base-patch16-224': 0.9475108225108224,
#  'apple/mobilevit-small': 0.9442640692640693,
#  'apple/mobilevit-xx-small': 0.8679653679653679,
# ...

# %%
# n_pars score vs val acc base
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="n_pars",
    # n_samples=15000,
    remove_outliers=False,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# n_pars score vs val acc no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="n_pars",
    # n_samples=15000,
    remove_outliers=True,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# n_pars score vs val acc ranked
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="n_pars",
    # n_samples=15000,
    remove_outliers=False,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# n_pars score vs val acc ranked no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="n_pars",
    # n_samples=15000,
    remove_outliers=True,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# renggli score vs val acc base
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="renggli",
    n_samples=10000,
    remove_outliers=False,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# renggli score vs val acc no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="renggli",
    n_samples=10000,
    remove_outliers=True,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# renggli score vs val acc ranked
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="renggli",
    n_samples=10000,
    remove_outliers=False,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# renggli score vs val acc ranked no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="renggli",
    n_samples=10000,
    remove_outliers=True,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# LogME score vs val acc base
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="LogME",
    n_samples=10000,
    remove_outliers=False,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# LogME score vs val acc no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="LogME",
    n_samples=10000,
    remove_outliers=True,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# LogME score vs val acc ranked
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="LogME",
    n_samples=10000,
    remove_outliers=False,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# LogME score vs val acc ranked no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=pets_mres,
    metric="LogME",
    n_samples=10000,
    remove_outliers=True,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %% [markdown]
# ImageNet scores vs. Val Acc can wait as I've got to go and find those for the ones we don't have in the original results. So onto rvl_cdip as wikiart hasn't quite finished yet.

# %% [markdown]
# ### rvl_cdip Graphs

# %% [markdown]
# Well as it turns out this is not going to work as this only ran the metrics and not the training.... So whilst I wait for `wikiart` to finish lets move onto ImageNet validation score comparisons.

# %% [markdown]
# ### ImageNet Val Acc Score Comparison

# %% [markdown]
# We have a validation accuracy for pets for the following:

# %%
pets_tres
# Out:
# {'microsoft/swinv2-base-patch4-window8-256': 0.961038961038961,
#  'Intel/vit-base-patch16-224-int8-static': 0.21645021645021645,
#  'microsoft/swin-base-patch4-window12-384': 0.9653679653679652,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.25,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.9659090909090908,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.29004329004329005,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.941017316017316,
#  'microsoft/beit-base-patch16-224': 0.9453463203463204,
#  'microsoft/beit-large-patch16-512': 0.9675324675324676,
#  'facebook/deit-base-patch16-384': 0.9648268398268398,
#  'microsoft/cvt-21-384-22k': 0.9518398268398268,
#  'microsoft/cvt-13': 0.9567099567099568,
#  'google/vit-large-patch16-224': 0.9437229437229436,
#  'google/vit-base-patch16-384': 0.9594155844155844,
#  'facebook/deit-base-patch16-224': 0.9475108225108224,
#  'apple/mobilevit-small': 0.9442640692640693,
#  'apple/mobilevit-xx-small': 0.8679653679653679,
# ...

# %% [markdown]
# And currently have Image net scores for the following:

# %%
with open("../configs/scores_imagenet1k.yaml", "r") as f:
    imagenet_val = yaml.safe_load(f)

imagenet_val
# Out:
# {'facebook/deit-tiny-patch16-224': 72.2,
#  'facebook/deit-small-patch16-224': 79.9,
#  'facebook/deit-base-patch16-224': 81.8,
#  'google/vit-base-patch16-384': 85.49,
#  'microsoft/cvt-13': 81.6,
#  'facebook/deit-tiny-distilled-patch16-224': 74.5,
#  'facebook/deit-small-distilled-patch16-224': 81.2,
#  'facebook/deit-base-distilled-patch16-224': 83.4,
#  'facebook/deit-base-patch16-384': 82.9,
#  'facebook/deit-base-distilled-patch16-384': 85.2,
#  'timm/eva_giant_patch14_336.clip_ft_in1k': 89.466,
#  'timm/eva02_large_patch14_448.mim_m38m_ft_in22k_in1k': 90.054,
#  'apple/mobilevit-small': 78.4,
#  'apple/mobilevit-xx-small': 69.0,
#  'microsoft/beit-large-patch16-512': 88.6,
#  'microsoft/swin-large-patch4-window12-384-in22k': 87.3,
#  'facebook/levit-128S': 76.6}

# %%
imgnet_val = {}

for model in pets_tres.keys():
    if model in imagenet_val.keys():
        imgnet_val[model] = imagenet_val[model]
    else:
        print(model)
# Out:
# microsoft/swinv2-base-patch4-window8-256
# Intel/vit-base-patch16-224-int8-static
# microsoft/swin-base-patch4-window12-384
# facebook/dinov2-base-imagenet1k-1-layer
# facebook/dinov2-small-imagenet1k-1-layer
# microsoft/beit-base-patch16-224-pt22k-ft22k
# microsoft/beit-base-patch16-224
# microsoft/cvt-21-384-22k
# google/vit-large-patch16-224

# %%
imgnet_val
# Out:
# {'microsoft/swin-large-patch4-window12-384-in22k': 87.3,
#  'microsoft/beit-large-patch16-512': 88.6,
#  'facebook/deit-base-patch16-384': 82.9,
#  'microsoft/cvt-13': 81.6,
#  'google/vit-base-patch16-384': 85.49,
#  'facebook/deit-base-patch16-224': 81.8,
#  'apple/mobilevit-small': 78.4,
#  'apple/mobilevit-xx-small': 69.0,
#  'facebook/deit-small-patch16-224': 79.9,
#  'facebook/deit-tiny-patch16-224': 72.2}

# %%
imgnet_val["microsoft/swinv2-base-patch4-window8-256"] = 84.0
imgnet_val["Intel/vit-base-patch16-224-int8-static"] = 80.576
imgnet_val["microsoft/swin-base-patch4-window12-384"] = 87.3
imgnet_val["facebook/dinov2-base-imagenet1k-1-layer"] = 84.5
imgnet_val["facebook/dinov2-small-imagenet1k-1-layer"] = 81.1
imgnet_val["microsoft/beit-base-patch16-224"] = 83.2
imgnet_val["microsoft/beit-base-patch16-224-pt22k-ft22k"] = 88.6
imgnet_val["microsoft/cvt-21-384-22k"] = 84.9
imgnet_val["google/vit-large-patch16-224"] = 87.76

# %%
imgnet_val
# Out:
# {'microsoft/swin-large-patch4-window12-384-in22k': 87.3,
#  'microsoft/beit-large-patch16-512': 88.6,
#  'facebook/deit-base-patch16-384': 82.9,
#  'microsoft/cvt-13': 81.6,
#  'google/vit-base-patch16-384': 85.49,
#  'facebook/deit-base-patch16-224': 81.8,
#  'apple/mobilevit-small': 78.4,
#  'apple/mobilevit-xx-small': 69.0,
#  'facebook/deit-small-patch16-224': 79.9,
#  'facebook/deit-tiny-patch16-224': 72.2,
#  'microsoft/swinv2-base-patch4-window8-256': 84.0,
#  'Intel/vit-base-patch16-224-int8-static': 80.576,
#  'microsoft/swin-base-patch4-window12-384': 87.3,
#  'facebook/dinov2-base-imagenet1k-1-layer': 84.5,
#  'facebook/dinov2-small-imagenet1k-1-layer': 81.1,
#  'microsoft/beit-base-patch16-224': 83.2,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 88.6,
#  'microsoft/cvt-21-384-22k': 84.9,
#  'google/vit-large-patch16-224': 87.76}

# %%
with open("new_scores_imagenet.yaml", "w") as f:
    yaml.safe_dump(imgnet_val, f)

# %%
img_net_val = {"imagenet_val": imgnet_val}

# %%
img_net_val
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/edable-heath/Documents/ARC-LoCoMoSeT/local_analysis/quick_analysis.ipynb Cell 105 line 1
# ----> <a href='vscode-notebook-cell:/Users/edable-heath/Documents/ARC-LoCoMoSeT/local_analysis/quick_analysis.ipynb#Y200sZmlsZQ%3D%3D?line=0'>1</a> img_net_val
#
# NameError: name 'img_net_val' is not defined

# %%
# imgnet val acc vs pets val acc base
plotter(
    val_acc=pets_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=10000,
    remove_outliers=False,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# imgnet val acc vs pets val acc no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=10000,
    remove_outliers=True,
    ranked=False,
    xy=False,
    dataset_name="Oxford Pets",
)

# %%
# imgnet val acc vs pets val acc ranked
plotter(
    val_acc=pets_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=10000,
    remove_outliers=False,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %%
# imgnet val acc vs pets val acc ranked no outliers
plotter(
    val_acc=pets_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=10000,
    remove_outliers=True,
    ranked=True,
    xy=True,
    dataset_name="Oxford Pets",
)

# %% [markdown]
# ### WikiArt Graphs

# %% [markdown]
# Lets create the wikiart graphs for now, re run this tomorrow morning when the final wiki_art is done!

# %%
wart_tres, wart_mres = pull_metric_and_train_data(
    "huggan/wikiart_20231117-102011-747776"
)

# %%
wart_var = np.var(list(wart_tres.values()))
wart_var**2
# Out:
# 0.00010169551725220368

# %%
wart_mean = np.mean(list(wart_tres.values()))
wart_mean
# Out:
# 0.7355677391504397

# %%
wart_tres_no_outliers = {
    k: v for k, v in wart_tres.items() if v > wart_mean - 3 * wart_var
}

# %%
wart_tres_outliers = {
    k: v for k, v in wart_tres.items() if v < wart_mean - 3 * wart_var
}

# %%
wart_tres_outliers
# Out:
# {'apple/mobilevit-small': 0.6446147045822896,
#  'Intel/vit-base-patch16-224-int8-static': 0.5543932026914199,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.5610235253671234,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.5634300869308974,
#  'apple/mobilevit-xx-small': 0.577820342812239}

# %%
wart_tres_no_outliers
# Out:
# {'microsoft/beit-large-patch16-512': 0.8426894553312706,
#  'microsoft/swin-base-patch4-window12-384': 0.8431805903442856,
#  'google/vit-base-patch16-384': 0.8113550415009086,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.8484848484848485,
#  'facebook/deit-base-patch16-384': 0.8032513137861598,
#  'microsoft/cvt-21-384-22k': 0.8193114287117529,
#  'microsoft/swinv2-base-patch4-window8-256': 0.8181327046805167,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.7684789548646923,
#  'microsoft/beit-base-patch16-224': 0.7660723933009185,
#  'microsoft/cvt-13': 0.7434801827022248,
#  'google/vit-large-patch16-224': 0.778792790138009,
#  'facebook/deit-small-patch16-224': 0.7482933058297726,
#  'facebook/deit-base-patch16-224': 0.7678404793477727,
#  'facebook/deit-tiny-patch16-224': 0.7151416924512548}

# %%
wart_tres
# Out:
# {'microsoft/beit-large-patch16-512': 0.8426894553312706,
#  'microsoft/swin-base-patch4-window12-384': 0.8431805903442856,
#  'google/vit-base-patch16-384': 0.8113550415009086,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.8484848484848485,
#  'facebook/deit-base-patch16-384': 0.8032513137861598,
#  'microsoft/cvt-21-384-22k': 0.8193114287117529,
#  'apple/mobilevit-small': 0.6446147045822896,
#  'microsoft/swinv2-base-patch4-window8-256': 0.8181327046805167,
#  'Intel/vit-base-patch16-224-int8-static': 0.5543932026914199,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.5610235253671234,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.5634300869308974,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.7684789548646923,
#  'microsoft/beit-base-patch16-224': 0.7660723933009185,
#  'microsoft/cvt-13': 0.7434801827022248,
#  'apple/mobilevit-xx-small': 0.577820342812239,
#  'google/vit-large-patch16-224': 0.778792790138009,
# ...

# %%
# n_pars acc vs wart val acc
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="n_pars",
    # n_samples=10000,
    remove_outliers=False,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# n_pars acc vs wart val acc no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="n_pars",
    # n_samples=10000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# n_pars acc vs wart val acc ranked
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="n_pars",
    # n_samples=10000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# n_pars acc vs wart val acc ranked no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="n_pars",
    # n_samples=10000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# renggli vs wart val acc
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="renggli",
    n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# renggli vs wart val acc no outlier
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="renggli",
    n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# renggli vs wart val acc ranked
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="renggli",
    n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# renggli vs wart val acc ranked no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="renggli",
    n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# LogME vs wart val acc
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="LogME",
    n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# LogME vs wart val acc no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="LogME",
    n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# LogME vs wart val acc ranked
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="LogME",
    n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# LogME vs wart val acc ranked no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=wart_mres,
    metric="LogME",
    n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# ImageNet val acc vs wart val acc
plotter(
    val_acc=wart_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# ImageNet val acc vs wart val acc no outliers
plotter(
    val_acc=wart_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=False,
    xy=False,
    dataset_name="WikiArt",
)

# %%
# ImageNet val acc vs wart val acc ranked
plotter(
    val_acc=wart_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=60000,
    remove_outliers=False,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %%
# ImageNet val acc vs wart val acc ranked
plotter(
    val_acc=wart_tres,
    metric_scores=img_net_val,
    metric="imagenet_val",
    # n_samples=60000,
    remove_outliers=True,
    outlier_threshold=0.7,
    ranked=True,
    xy=True,
    dataset_name="WikiArt",
)

# %% [markdown]
# ### Pets again

# %% [markdown]
# This time with better variation in the `no_samples` parameters.

# %%
_, petA_mres = pull_metric_and_train_data("pcuenq/oxford-pets_20231121-190822-362963")

# %%
logme = {}
n_samps = []

for n_samp in sorted(petA_mres["LogME"].keys()):
    n_samps.append(n_samp)
    for model in petA_mres["LogME"][n_samp]:
        if logme.get(model) is not None:
            logme[model].append(petA_mres["LogME"][n_samp][model])
        else:
            logme[model] = []
            logme[model].append(petA_mres["LogME"][n_samp][model])

# %%
renggli = {}
for n_samp in sorted(petA_mres["renggli"].keys()):
    for model in petA_mres["renggli"][n_samp]:
        if renggli.get(model) is not None:
            renggli[model].append(petA_mres["renggli"][n_samp][model])
        else:
            renggli[model] = []
            renggli[model].append(petA_mres["renggli"][n_samp][model])

# %%
renggli.pop("Intel/vit-base-patch16-224-int8-static")
# Out:
# [0.088,
#  0.128,
#  0.102,
#  0.11428571428571428,
#  0.1338181818181818,
#  0.14502164502164502]

# %%
fig, ax = plt.subplots(1)
for model in renggli.keys():
    ax.scatter(n_samps, renggli[model])
    ax.plot(n_samps, renggli[model])

ax.set_xlabel("Number of Samples")
ax.set_ylabel("Renggli Score")
fig.suptitle("Oxford Pets: Renggli Metric Score vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'Oxford Pets: Renggli Metric Score vs. No of Image Samples')

# %%
fig, ax = plt.subplots(1)
for model in logme.keys():
    ax.scatter(n_samps, logme[model])
    ax.plot(n_samps, logme[model])

ax.set_xlabel("Number of Samples")
ax.set_ylabel("LogME Score")
ax.set_xscale("log")
fig.suptitle("Oxford Pets: LogME Metric Score vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'Oxford Pets: LogME Metric Score vs. No of Image Samples')

# %%
logme.pop("Intel/vit-base-patch16-224-int8-static")
# Out:
# [3.3611969239689494,
#  0.4051249216360153,
#  0.4050326790003615,
#  0.4068509184897649,
#  0.40846876743579097,
#  0.4091442270910721]

# %% [markdown]
# Now lets do a similar thing but for correlations with the validation accuracy.

# %%
n_samps = {}
met_scores = {}
metric_scores = petA_mres["LogME"]
for n_samp in metric_scores.keys():
    for model in metric_scores[n_samp].keys():
        if model not in met_scores.keys():
            met_scores[model] = []
            n_samps[model] = []
        met_scores[model].append(metric_scores[n_samp][model])
        n_samps[model].append(n_samp)

# %%
from locomoset.plots.utils import plot_results

# %%
plot_results(
    met_scores,
    n_samps,
    "y",
    metric_label="logme",
    other_label="samps",
    title="test",
    save_path=".",
    log_scale=True,
)
# Out:
# Saved figure to .
# <Axes: title={'center': 'test'}, xlabel='samps', ylabel='logme'>

# %%
logme = []
n_samps = []

for n_samp in sorted(petA_mres["LogME"].keys()):
    n_samps.append(n_samp)
    logme.append(
        spearmanr(
            [petA_mres["LogME"][n_samp][model] for model in pets_tres.keys()],
            [pets_tres[model] for model in pets_tres.keys()],
        )[0]
    )

# %%
fig, ax = plt.subplots(1)
ax.scatter(n_samps, logme)
ax.plot(n_samps, logme)

ax.set_xlabel("Number of Samples")
ax.set_ylabel("LogME/Val acc correlation")
ax.set_xscale("log")
fig.suptitle("Oxford Pets: LogME Metric/Val acc Correlation vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'Oxford Pets: LogME Metric/Val acc Correlation vs. No of Image Samples')

# %%
renggli = []
n_samps = []

for n_samp in sorted(petA_mres["renggli"].keys()):
    n_samps.append(n_samp)

    renggli.append(
        spearmanr(
            [petA_mres["renggli"][n_samp][model] for model in pets_tres.keys()],
            [pets_tres[model] for model in pets_tres.keys()],
        )[0]
    )

# %%
fig, ax = plt.subplots(1)
ax.scatter(n_samps, renggli)
ax.plot(n_samps, renggli)

ax.set_xlabel("Number of Samples")
ax.set_ylabel("Renggli/Val acc correlation")
# ax.set_xscale("log")
fig.suptitle("Oxford Pets: Renggli Metric/Val acc Correlation vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'Oxford Pets: Renggli Metric/Val acc Correlation vs. No of Image Samples')

# %% [markdown]
# ### Now lets do the same for `WikiArt`

# %%
logme = {}
n_samps = []

for n_samp in sorted(wart_mres["LogME"].keys()):
    n_samps.append(n_samp)
    for model in wart_mres["LogME"][n_samp]:
        if logme.get(model) is not None:
            logme[model].append(wart_mres["LogME"][n_samp][model])
        else:
            logme[model] = []
            logme[model].append(wart_mres["LogME"][n_samp][model])

# %%
renggli = {}
for n_samp in sorted(wart_mres["renggli"].keys()):
    for model in wart_mres["renggli"][n_samp]:
        if renggli.get(model) is not None:
            renggli[model].append(wart_mres["renggli"][n_samp][model])
        else:
            renggli[model] = []
            renggli[model].append(wart_mres["renggli"][n_samp][model])

# %%
fig, ax = plt.subplots(1)
for model in renggli.keys():
    ax.scatter(n_samps, renggli[model])
    ax.plot(n_samps, renggli[model])

ax.set_xlabel("Number of Samples")
ax.set_ylabel("Renggli Score")
fig.suptitle("WikiArt: Renggli Metric Score vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'WikiArt: Renggli Metric Score vs. No of Image Samples')

# %%
logme.pop("Intel/vit-base-patch16-224-int8-static")
# Out:
# [5.99606235112084,
#  1.8583367405912936,
#  1.5026419618238112,
#  1.5060548189857388,
#  1.50293428626063]

# %%
fig, ax = plt.subplots(1)
for model in logme.keys():
    ax.scatter(n_samps, logme[model])
    ax.plot(n_samps, logme[model])

ax.set_xlabel("Number of Samples")
ax.set_ylabel("LogME Score")
ax.set_xscale("log")
fig.suptitle("WikiArt: LogME Metric Score vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'WikiArt: LogME Metric Score vs. No of Image Samples')

# %%
wart_tres
# Out:
# {'microsoft/beit-large-patch16-512': 0.8426894553312706,
#  'microsoft/swin-base-patch4-window12-384': 0.8431805903442856,
#  'google/vit-base-patch16-384': 0.8113550415009086,
#  'microsoft/swin-large-patch4-window12-384-in22k': 0.8484848484848485,
#  'facebook/deit-base-patch16-384': 0.8032513137861598,
#  'microsoft/cvt-21-384-22k': 0.8193114287117529,
#  'apple/mobilevit-small': 0.6446147045822896,
#  'microsoft/swinv2-base-patch4-window8-256': 0.8181327046805167,
#  'Intel/vit-base-patch16-224-int8-static': 0.5543932026914199,
#  'facebook/dinov2-base-imagenet1k-1-layer': 0.5610235253671234,
#  'facebook/dinov2-small-imagenet1k-1-layer': 0.5634300869308974,
#  'microsoft/beit-base-patch16-224-pt22k-ft22k': 0.7684789548646923,
#  'microsoft/beit-base-patch16-224': 0.7660723933009185,
#  'microsoft/cvt-13': 0.7434801827022248,
#  'apple/mobilevit-xx-small': 0.577820342812239,
#  'google/vit-large-patch16-224': 0.778792790138009,
# ...

# %%
logme = []
n_samps = []

for n_samp in sorted(wart_mres["LogME"].keys()):
    n_samps.append(n_samp)
    logme.append(
        spearmanr(
            [wart_mres["LogME"][n_samp][model] for model in wart_tres.keys()],
            [wart_tres[model] for model in wart_tres.keys()],
        )[0]
    )

# %%
fig, ax = plt.subplots(1)
ax.scatter(n_samps, logme)
ax.plot(n_samps, logme)

ax.set_xlabel("Number of Samples")
ax.set_ylabel("LogME/Val acc correlation")
# ax.set_xscale("log")
fig.suptitle("WikiArt: LogME Metric/Val acc Correlation vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'WikiArt: LogME Metric/Val acc Correlation vs. No of Image Samples')

# %%
renggli = []
n_samps = []

for n_samp in sorted(wart_mres["renggli"].keys()):
    n_samps.append(n_samp)
    renggli.append(
        spearmanr(
            [wart_mres["renggli"][n_samp][model] for model in wart_tres.keys()],
            [wart_tres[model] for model in wart_tres.keys()],
        )[0]
    )

# %%
fig, ax = plt.subplots(1)
ax.scatter(n_samps, renggli)
ax.plot(n_samps, renggli)

ax.set_xlabel("Number of Samples")
ax.set_ylabel("Renggli/Val acc correlation")
# ax.set_xscale("log")
fig.suptitle("WikiArt: Renggli Metric/Val acc Correlation vs. No of Image Samples")
# Out:
# Text(0.5, 0.98, 'WikiArt: Renggli Metric/Val acc Correlation vs. No of Image Samples')

# %% [markdown]
# ## Jan 2024 Results

# %%
import pandas as pd
import wandb


def pull_metric_and_train_data(group_name: str):
    """Pull metric and train data from weights and biases, turning it into the requisite
    dict structure for the plotting functions above"""

    api = wandb.Api()

    # Project is specified by <entity/project-name>
    train_runs = api.runs(
        path="turing-arc/locomoset",
        filters={"group": group_name, "jobType": "train"},
    )

    summary_train, config_train, name_train = [], [], []
    for run in train_runs:
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        summary_train.append(run.summary._json_dict)

        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        config_train.append(
            {k: v for k, v in run.config.items() if not k.startswith("_")}
        )

        # .name is the human-readable name of the run.
        name_train.append(run.name)

    train_df = pd.DataFrame(
        {"summary": summary_train, "config": config_train, "name": name_train}
    )

    train_res = {}

    for _, row in train_df.iterrows():
        if row.summary.get("eval/accuracy") is not None:
            if train_res.get(row.config["locomoset"]["n_samples"]) is not None:
                train_res[row.config["locomoset"]["n_samples"]][
                    row.config["locomoset"].get("model_name")
                ] = row.summary.get("eval/accuracy")
            else:
                train_res[row.config["locomoset"]["n_samples"]] = {}
                train_res[row.config["locomoset"]["n_samples"]][
                    row.config["locomoset"].get("model_name")
                ] = row.summary.get("eval/accuracy")

    metric_runs = api.runs(
        path="turing-arc/locomoset",
        filters={
            "group": group_name,
            "jobType": "metrics",
        },
    )

    summary_metrics, config_metrics, name_metrics = [], [], []
    for run in metric_runs:
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        summary_metrics.append(run.summary._json_dict)

        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        config_metrics.append(
            {k: v for k, v in run.config.items() if not k.startswith("_")}
        )

        # .name is the human-readable name of the run.
        name_metrics.append(run.name)

    metrics_df = pd.DataFrame(
        {"summary": summary_metrics, "config": config_metrics, "name": name_metrics}
    )

    metric_results = {}

    for _, row in metrics_df.iterrows():
        for met in row.summary["metric_scores"].keys():
            if metric_results.get(met) is not None:
                if met == "n_pars":
                    metric_results[met][row.summary["model_name"]] = row.summary[
                        "metric_scores"
                    ][met]["score"]
                else:
                    if metric_results[met].get(row.summary["n_samples"]) is not None:
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
                    else:
                        metric_results[met][row.summary["n_samples"]] = {}
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
            else:
                metric_results[met] = {}
                if met == "n_pars":
                    metric_results[met][row.summary["model_name"]] = row.summary[
                        "metric_scores"
                    ][met]["score"]
                else:
                    if metric_results[met].get(row.summary["n_samples"]) is not None:
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]
                    else:
                        metric_results[met][row.summary["n_samples"]] = {}
                        metric_results[met][row.summary["n_samples"]][
                            row.summary["model_name"]
                        ] = row.summary["metric_scores"][met]["score"]

    return train_res, metric_results

# %%
rcdip_tres, rcdip_mres = pull_metric_and_train_data("aharley/rvl_cdip_20240105")

# %%
rcdip_mres
# Out:
# {'n_pars': {'microsoft/cvt-13': 19612480,
#   'microsoft/beit-base-patch16-384': 85975104,
#   'microsoft/beit-base-patch16-224': 85761984,
#   'facebook/deit-base-patch16-224': 85798656,
#   'facebook/deit-small-patch16-224': 21665664,
#   'apple/mobilevit-small': 4937632,
#   'facebook/deit-tiny-patch16-224': 5524416,
#   'apple/mobilevit-xx-small': 951024,
#   'facebook/dinov2-base-imagenet1k-1-layer': 86580480,
#   'facebook/dinov2-small-imagenet1k-1-layer': 22056576,
#   'Zetatech/pvt-large-224': 60856320,
#   'microsoft/swinv2-base-patch4-window8-256': 86893816,
#   'microsoft/swin-base-patch4-window12-384': 86878584,
#   'microsoft/cvt-21-384': 31237696,
#   'google/vit-large-patch16-224': 303301632,
#   'google/vit-base-patch16-384': 86090496,
#   'facebook/deit-base-patch16-384': 86090496,
#   'microsoft/beit-large-patch16-512': 304649728,
#   'microsoft/swinv2-large-patch4-window12to16-192to256-22kto1k-ft': 195202932,
# ...

# %%
rcdip_tres.keys()
# Out:
# dict_keys([50000, 10000, 5000, 1000, 500])

# %%
def plot_all(vals, mets, met, ranked=False, xy=False, dataset_name=None):
    for n in vals.keys():
        if met == "n_pars":
            n = None
        plotter(
            val_acc=vals[n],
            metric_scores=mets,
            metric=met,
            n_samples=n,
            ranked=ranked,
            xy=xy,
            dataset_name=dataset_name,
        )

# %%
ptres, pmres = pull_metric_and_train_data("pcuenq/oxford-pets_20240105")

# %%
wtres, wmres = pull_metric_and_train_data("huggan/wikiart_20240105")

# %%
len(wtres[500].keys())
# Out:
# 20

# %%
plot_all(ptres, pmres, "renggli", ranked=True, xy=True, dataset_name="Pets")

# %%
for n in sorted(rcdip_tres.keys()):
    print(f"model count for rvlcdip at {n} samples is {len(rcdip_tres[n].keys())}")

print("---------------------------------")

for n in sorted(wtres.keys()):
    print(f"model count for wikiart at {n} samples is {len(wtres[n].keys())}")

print("---------------------------------")

for n in sorted(ptres.keys()):
    print(f"model count for pets at {n} samples is {len(ptres[n].keys())}")
# Out:
# model count for rvlcdip at 500 samples is 20
# model count for rvlcdip at 1000 samples is 20
# model count for rvlcdip at 5000 samples is 20
# model count for rvlcdip at 10000 samples is 19
# model count for rvlcdip at 50000 samples is 20
# ---------------------------------
# model count for wikiart at 500 samples is 20
# model count for wikiart at 1000 samples is 20
# model count for wikiart at 5000 samples is 12
# model count for wikiart at 10000 samples is 20
# model count for wikiart at 50000 samples is 12
# ---------------------------------
# model count for pets at 500 samples is 20
# model count for pets at 1000 samples is 20
# model count for pets at 4803 samples is 20

# %% [markdown]
# ## Binary Datasets Analysis

# %%
api = wandb.Api()

# Project is specified by <entity/project-name>
train_runs = api.runs(
    path="turing-arc/locomoset",
    filters={"group": "inary_datasets/bin_faucet_20240110", "jobType": "train"},
)

# %%
summary_train, config_train, name_train = [], [], []
for run in train_runs:
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files
    summary_train.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_train.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_train.append(run.name)

train_df = pd.DataFrame(
    {"summary": summary_train, "config": config_train, "name": name_train}
)

# %%
train_df.summary[3]["eval/accuracy"]
# Out:
# 0.944
